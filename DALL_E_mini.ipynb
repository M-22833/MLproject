# %%
# !pip install min-dalle -q

# %%
from min_dalle import MinDalle
model = MinDalle(is_mega = True, is_reusable = True)
# Out:
# using device cuda
# intializing TextTokenizer
# initializing DalleBartEncoder
# initializing DalleBartDecoder
# downloading detokenizer params
# initializing VQGanDetokenizer

# %%
# %%time

text = input("Enter Description: ")
seed = 7
grid_size = 3
model.generate_image(text, seed, grid_size)
# Out:
# Enter Description: a man with long beard round face sharp nose blue eyes
# CPU times: user 50.6 s, sys: 1.91 s, total: 52.5 s
# Wall time: 1min 40s
# <PIL.Image.Image image mode=RGB size=768x768 at 0x7FA2D1BBAE20>
